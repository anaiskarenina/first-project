# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import sklearn

# %%
df = pd.read_csv(r"C:\Users\egimenez\Downloads\llamados-atendidos-violencia-familiar-202110.csv")

# %% [markdown]
# # Exploration

# %%
df.head()
# Out:
#    caso_id                              llamante_descripcion llamante_genero  \
# 0   432086                                         Comisaría       Masculino
# 1   432090                                           Víctima       Masculino
# 2   346145                                           Víctima        Femenino
# 3   432091  Otra/o sobre una situación de conflicto familiar           NS/NC
# 4   432093                                             NS/NC       Masculino
#
#   llamante_vinculo_ninios_presentes        violencia_tipo victima_edad  \
# 0                   No hay niñas/os  Física y psicológica           43
# 1                   No hay niñas/os  Física y psicológica           65
# 2                             Madre  Física y psicológica           26
# 3                             NS/NC             No aplica    Sin dato
# 4                             NS/NC           Psicológica    Sin dato
#
#   victima_rango_etario victima_genero  victima_cantidad  agresor_cantidad  \
# 0         40 a 49 años       Femenino                 1                 1
# 1       Más de 60 años      Masculino                 2                 1
# 2         18 a 29 años       Femenino                 3                 1
# 3            Sin dato           NS/NC                 0                 0
# 4            Sin dato           NS/NC                 1                 1
#
#   agresor_genero agresor_relacion_victima  \
# 0      Masculino                Hermano/a
# 1      Masculino                   Hijo/a
# 2      Masculino                Ex pareja
# 3          NS/NC                    NS/NC
# 4          NS/NC                    NS/NC
#
#                               llamado_derivacion llamado_fecha llamado_hora  \
# 0  Llamante solicitó información y/o orientación    2021-01-01         2:56
# 1  Llamante solicitó información y/o orientación    2021-01-01         8:37
# 2  Llamante solicitó información y/o orientación    2021-01-01        11:16
# 3              Se trata de un conflicto familiar    2021-01-01        11:38
# 4  Llamante solicitó información y/o orientación    2021-01-01        11:44
#
#                  llamado_provincia  llamado_provincia_id
# 0  Ciudad Autónoma de Buenos Aires                     2
# 1  Ciudad Autónoma de Buenos Aires                     2
# 2  Ciudad Autónoma de Buenos Aires                     2
# 3  Ciudad Autónoma de Buenos Aires                     2
# 4  Ciudad Autónoma de Buenos Aires                     2

# %%
df = df.drop(df.columns[[0, 15, 16]], axis = 1)

# %%
df.shape
# Out:
# (7801, 14)

# %%
df.describe(include = "all")
# Out:
#        llamante_descripcion llamante_genero llamante_vinculo_ninios_presentes  \
# count                  7801            7801                              7801
# unique                   12               4                                 8
# top                 Víctima        Femenino                             NS/NC
# freq                   3129            4822                              2496
# mean                    NaN             NaN                               NaN
# std                     NaN             NaN                               NaN
# min                     NaN             NaN                               NaN
# 25%                     NaN             NaN                               NaN
# 50%                     NaN             NaN                               NaN
# 75%                     NaN             NaN                               NaN
# max                     NaN             NaN                               NaN
#
#        violencia_tipo victima_edad victima_rango_etario victima_genero  \
# count            7801         7801                 7187           7801
# unique              8           98                    9              4
# top       Psicológica    Sin dato             Sin dato        Femenino
# freq             3503         4227                 3924           4489
# mean              NaN          NaN                  NaN            NaN
# std               NaN          NaN                  NaN            NaN
# min               NaN          NaN                  NaN            NaN
# 25%               NaN          NaN                  NaN            NaN
# 50%               NaN          NaN                  NaN            NaN
# 75%               NaN          NaN                  NaN            NaN
# max               NaN          NaN                  NaN            NaN
#
#         victima_cantidad  agresor_cantidad agresor_genero  \
# count        7801.000000       7801.000000           7801
# unique               NaN               NaN              3
# top                  NaN               NaN      Masculino
# freq                 NaN               NaN           3916
# mean            1.263684          0.919882            NaN
# std             1.112666          0.554576            NaN
# min             0.000000          0.000000            NaN
# 25%             1.000000          1.000000            NaN
# 50%             1.000000          1.000000            NaN
# 75%             2.000000          1.000000            NaN
# max            13.000000          7.000000            NaN
#
#        agresor_relacion_victima  \
# count                      7801
# unique                       12
# top                       NS/NC
# freq                       2240
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
#
#                                    llamado_derivacion llamado_fecha  \
# count                                            7801          7801
# unique                                             11           304
# top     Llamante solicitó información y/o orientación    2021-05-06
# freq                                             5298            58
# mean                                              NaN           NaN
# std                                               NaN           NaN
# min                                               NaN           NaN
# 25%                                               NaN           NaN
# 50%                                               NaN           NaN
# 75%                                               NaN           NaN
# max                                               NaN           NaN
#
#        llamado_hora
# count          7801
# unique         1381
# top           12:52
# freq             20
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %% [markdown]
# # Making list of missing values

# %%
missing_values = ["Sin dato ", "NS/NC"]
df = pd.read_csv(r"C:\Users\egimenez\Downloads\llamados-atendidos-violencia-familiar-202110.csv", na_values = missing_values)

# %%
display(df.dtypes.value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of caso_id                                int64
# llamante_descripcion                  object
# llamante_genero                       object
# llamante_vinculo_ninios_presentes     object
# violencia_tipo                        object
# victima_edad                         float64
# victima_rango_etario                  object
# victima_genero                        object
# victima_cantidad                       int64
# agresor_cantidad                       int64
# agresor_genero                        object
# agresor_relacion_victima              object
# llamado_derivacion                    object
# llamado_fecha                         object
# llamado_hora                          object
# llamado_provincia                     object
# llamado_provincia_id                   int64
# dtype: object>

# %% [markdown]
# # Adjust data types

# %%
df['llamado_fecha'] = pd.to_datetime(df['llamado_fecha'])
df['victima_edad'] = pd.to_numeric(df['victima_edad'])

# %%
display(df.dtypes.value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of caso_id                                       int64
# llamante_descripcion                         object
# llamante_genero                              object
# llamante_vinculo_ninios_presentes            object
# violencia_tipo                               object
# victima_edad                                float64
# victima_rango_etario                         object
# victima_genero                               object
# victima_cantidad                              int64
# agresor_cantidad                              int64
# agresor_genero                               object
# agresor_relacion_victima                     object
# llamado_derivacion                           object
# llamado_fecha                        datetime64[ns]
# llamado_hora                                 object
# llamado_provincia                            object
# llamado_provincia_id                          int64
# dtype: object>

# %%
num_vars = df.columns[df.dtypes != 'object']
cat_vars = df.columns[df.dtypes == 'object']

# %% [markdown]
# # Check how many missing values are

# %%
df[num_vars].isnull().sum()/len(df) * 100
# Out:
# caso_id                  0.000000
# victima_edad            54.185361
# victima_cantidad         0.000000
# agresor_cantidad         0.000000
# llamado_fecha            0.000000
# llamado_provincia_id     0.000000
# dtype: float64

# %%
df[cat_vars].isnull().sum()/len(df) * 100
# Out:
# llamante_descripcion                  5.576208
# llamante_genero                      21.048584
# llamante_vinculo_ninios_presentes    31.995898
# violencia_tipo                        0.000000
# victima_rango_etario                 58.172029
# victima_genero                       27.932316
# agresor_genero                       28.996283
# agresor_relacion_victima             28.714267
# llamado_derivacion                    0.000000
# llamado_hora                          0.000000
# llamado_provincia                     0.000000
# dtype: float64

# %% [markdown]
# # Find and delete calls with majority of missing values

# %%
llamante_profesional = df[df['llamante_descripcion'] == 'Profesionales de la Línea 137']

# %%
llamante_profesional.isnull().sum()*100 / len(llamante_profesional)
# Out:
# caso_id                                0.0
# llamante_descripcion                   0.0
# llamante_genero                      100.0
# llamante_vinculo_ninios_presentes    100.0
# violencia_tipo                         0.0
# victima_edad                         100.0
# victima_rango_etario                 100.0
# victima_genero                       100.0
# victima_cantidad                       0.0
# agresor_cantidad                       0.0
# agresor_genero                       100.0
# agresor_relacion_victima             100.0
# llamado_derivacion                     0.0
# llamado_fecha                          0.0
# llamado_hora                           0.0
# llamado_provincia                      0.0
# llamado_provincia_id                   0.0
# dtype: float64

# %%
df = df.loc[df['llamante_descripcion'] != 'Profesionales de la Línea 137']

# %%
df.shape
# Out:
# (7152, 17)

# %%
llamante_otro = df[df['llamante_descripcion'] == 'Otra/o sobre una situación de conflicto familiar']

# %%
llamante_otro.isnull().sum()*100 / len(llamante_otro)
# Out:
# caso_id                                0.000000
# llamante_descripcion                   0.000000
# llamante_genero                       10.559006
# llamante_vinculo_ninios_presentes     27.795031
# violencia_tipo                         0.000000
# victima_edad                         100.000000
# victima_rango_etario                 100.000000
# victima_genero                       100.000000
# victima_cantidad                       0.000000
# agresor_cantidad                       0.000000
# agresor_genero                       100.000000
# agresor_relacion_victima             100.000000
# llamado_derivacion                     0.000000
# llamado_fecha                          0.000000
# llamado_hora                           0.000000
# llamado_provincia                      0.000000
# llamado_provincia_id                   0.000000
# dtype: float64

# %%
llamante_otro.shape
# Out:
# (644, 17)

# %%
df = df.loc[df['llamante_descripcion'] != 'Otra/o sobre una situación de conflicto familiar']

# %%
df.shape
# Out:
# (6508, 17)

# %%
llamante_otro2 = df[df['llamante_descripcion'] == 'Otro/a']

# %%
llamante_otro2.isnull().sum()*100 / len(llamante_otro2)
# Out:
# caso_id                               0.000000
# llamante_descripcion                  0.000000
# llamante_genero                      24.681934
# llamante_vinculo_ninios_presentes    32.315522
# violencia_tipo                        0.000000
# victima_edad                         54.707379
# victima_rango_etario                 58.269720
# victima_genero                        9.923664
# victima_cantidad                      0.000000
# agresor_cantidad                      0.000000
# agresor_genero                       16.030534
# agresor_relacion_victima             13.740458
# llamado_derivacion                    0.000000
# llamado_fecha                         0.000000
# llamado_hora                          0.000000
# llamado_provincia                     0.000000
# llamado_provincia_id                  0.000000
# dtype: float64

# %%
llamante_otro2.shape
# Out:
# (393, 17)

# %%
df = df.loc[df['llamante_descripcion'] != 'Otro/a']

# %%
df.shape
# Out:
# (6115, 17)

# %%
df[cat_vars].isnull().sum()/len(df) * 100
# Out:
# llamante_descripcion                  7.113655
# llamante_genero                      13.540474
# llamante_vinculo_ninios_presentes    25.200327
# violencia_tipo                        0.000000
# victima_rango_etario                 49.321341
# victima_genero                       13.851186
# agresor_genero                       14.816026
# agresor_relacion_victima             14.603434
# llamado_derivacion                    0.000000
# llamado_hora                          0.000000
# llamado_provincia                     0.000000
# dtype: float64

# %%
df[num_vars].isnull().sum()/len(df) * 100
# Out:
# caso_id                  0.000000
# victima_edad            44.464432
# victima_cantidad         0.000000
# agresor_cantidad         0.000000
# llamado_fecha            0.000000
# llamado_provincia_id     0.000000
# dtype: float64

# %% [markdown]
# # Group data by different categories

# %%
edad_victima = df.groupby('victima_rango_etario').count()

edad_victima.sort_values(by='caso_id', ascending=False)
# Out:
#                       caso_id  llamante_descripcion  llamante_genero  \
# victima_rango_etario
# 18 a 29 años              769                   764              757
# 30 a 39 años              530                   529              529
# 12 a 17 años              429                   421              410
# Más de 60 años            385                   380              378
# 40 a 49 años              378                   378              375
# 06 a 11 años              223                   218              214
# 0 a 5 años                201                   194              190
# 50 a 59 años              184                   184              182
#
#                       llamante_vinculo_ninios_presentes  violencia_tipo  \
# victima_rango_etario
# 18 a 29 años                                        619             769
# 30 a 39 años                                        472             530
# 12 a 17 años                                        354             429
# Más de 60 años                                      343             385
# 40 a 49 años                                        334             378
# 06 a 11 años                                        209             223
# 0 a 5 años                                          189             201
# 50 a 59 años                                        159             184
#
#                       victima_edad  victima_genero  victima_cantidad  \
# victima_rango_etario
# 18 a 29 años                   769             758               769
# 30 a 39 años                   530             529               530
# 12 a 17 años                   429             418               429
# Más de 60 años                 385             384               385
# 40 a 49 años                   378             375               378
# 06 a 11 años                   223             223               223
# 0 a 5 años                     201             197               201
# 50 a 59 años                   184             184               184
#
#                       agresor_cantidad  agresor_genero  \
# victima_rango_etario
# 18 a 29 años                       769             741
# 30 a 39 años                       530             521
# 12 a 17 años                       429             413
# Más de 60 años                     385             366
# 40 a 49 años                       378             366
# 06 a 11 años                       223             213
# 0 a 5 años                         201             182
# 50 a 59 años                       184             180
#
#                       agresor_relacion_victima  llamado_derivacion  \
# victima_rango_etario
# 18 a 29 años                               743                 769
# 30 a 39 años                               518                 530
# 12 a 17 años                               414                 429
# Más de 60 años                             376                 385
# 40 a 49 años                               367                 378
# 06 a 11 años                               213                 223
# 0 a 5 años                                 182                 201
# 50 a 59 años                               181                 184
#
#                       llamado_fecha  llamado_hora  llamado_provincia  \
# victima_rango_etario
# 18 a 29 años                    769           769                769
# 30 a 39 años                    530           530                530
# 12 a 17 años                    429           429                429
# Más de 60 años                  385           385                385
# 40 a 49 años                    378           378                378
# 06 a 11 años                    223           223                223
# 0 a 5 años                      201           201                201
# 50 a 59 años                    184           184                184
#
#                       llamado_provincia_id
# victima_rango_etario
# 18 a 29 años                           769
# 30 a 39 años                           530
# 12 a 17 años                           429
# Más de 60 años                         385
# 40 a 49 años                           378
# 06 a 11 años                           223
# 0 a 5 años                             201
# 50 a 59 años                           184

# %%
edad_victima.plot.bar(y = 'caso_id', legend=None)
plt.ylabel("Cantidad de casos")
plt.xlabel("Rango etario de la víctima")
# Out:
# Text(0.5, 0, 'Rango etario de la víctima')

# %%
derivacion = df.groupby('llamado_derivacion').count()

derivacion.sort_values(by='caso_id', ascending=False)
# Out:
#                                                     caso_id  \
# llamado_derivacion
# Llamante solicitó información y/o orientación          4917
# No se desplazó un Equipo móvil por tratarse de ...      704
# La víctima no aceptó la intervención del Equipo...      195
# No había móviles y/o Equipos para realizar la i...       97
# Está interviniendo o se deriva a otra institución        74
# Desplazamiento de un Equipo Móvil a donde se en...       53
# Se planificó intervención para otro momento              45
# Comunicación con los Equipos Móviles                     20
# Se trata de un conflicto familiar                         6
# Otras                                                     4
#
#                                                     llamante_descripcion  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                       4494
# No se desplazó un Equipo móvil por tratarse de ...                   696
# La víctima no aceptó la intervención del Equipo...                   195
# No había móviles y/o Equipos para realizar la i...                    97
# Está interviniendo o se deriva a otra institución                     73
# Desplazamiento de un Equipo Móvil a donde se en...                    51
# Se planificó intervención para otro momento                           45
# Comunicación con los Equipos Móviles                                  20
# Se trata de un conflicto familiar                                      6
# Otras                                                                  3
#
#                                                     llamante_genero  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                  4105
# No se desplazó un Equipo móvil por tratarse de ...              694
# La víctima no aceptó la intervención del Equipo...              194
# No había móviles y/o Equipos para realizar la i...               97
# Está interviniendo o se deriva a otra institución                72
# Desplazamiento de un Equipo Móvil a donde se en...               52
# Se planificó intervención para otro momento                      45
# Comunicación con los Equipos Móviles                             20
# Se trata de un conflicto familiar                                 5
# Otras                                                             3
#
#                                                     llamante_vinculo_ninios_presentes  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                                    3476
# No se desplazó un Equipo móvil por tratarse de ...                                644
# La víctima no aceptó la intervención del Equipo...                                182
# No había móviles y/o Equipos para realizar la i...                                 91
# Está interviniendo o se deriva a otra institución                                  69
# Desplazamiento de un Equipo Móvil a donde se en...                                 48
# Se planificó intervención para otro momento                                        37
# Comunicación con los Equipos Móviles                                               19
# Se trata de un conflicto familiar                                                   5
# Otras                                                                               3
#
#                                                     violencia_tipo  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                 4917
# No se desplazó un Equipo móvil por tratarse de ...             704
# La víctima no aceptó la intervención del Equipo...             195
# No había móviles y/o Equipos para realizar la i...              97
# Está interviniendo o se deriva a otra institución               74
# Desplazamiento de un Equipo Móvil a donde se en...              53
# Se planificó intervención para otro momento                     45
# Comunicación con los Equipos Móviles                            20
# Se trata de un conflicto familiar                                6
# Otras                                                            4
#
#                                                     victima_edad  \
# llamado_derivacion
# Llamante solicitó información y/o orientación               2534
# No se desplazó un Equipo móvil por tratarse de ...           488
# La víctima no aceptó la intervención del Equipo...           167
# No había móviles y/o Equipos para realizar la i...            68
# Está interviniendo o se deriva a otra institución             42
# Desplazamiento de un Equipo Móvil a donde se en...            44
# Se planificó intervención para otro momento                   32
# Comunicación con los Equipos Móviles                          17
# Se trata de un conflicto familiar                              3
# Otras                                                          1
#
#                                                     victima_rango_etario  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                       2320
# No se desplazó un Equipo móvil por tratarse de ...                   439
# La víctima no aceptó la intervención del Equipo...                   153
# No había móviles y/o Equipos para realizar la i...                    58
# Está interviniendo o se deriva a otra institución                     40
# Desplazamiento de un Equipo Móvil a donde se en...                    40
# Se planificó intervención para otro momento                           30
# Comunicación con los Equipos Móviles                                  17
# Se trata de un conflicto familiar                                      2
# Otras                                                                  0
#
#                                                     victima_genero  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                 4132
# No se desplazó un Equipo móvil por tratarse de ...             662
# La víctima no aceptó la intervención del Equipo...             193
# No había móviles y/o Equipos para realizar la i...              93
# Está interviniendo o se deriva a otra institución               65
# Desplazamiento de un Equipo Móvil a donde se en...              51
# Se planificó intervención para otro momento                     45
# Comunicación con los Equipos Móviles                            19
# Se trata de un conflicto familiar                                5
# Otras                                                            3
#
#                                                     victima_cantidad  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                   4917
# No se desplazó un Equipo móvil por tratarse de ...               704
# La víctima no aceptó la intervención del Equipo...               195
# No había móviles y/o Equipos para realizar la i...                97
# Está interviniendo o se deriva a otra institución                 74
# Desplazamiento de un Equipo Móvil a donde se en...                53
# Se planificó intervención para otro momento                       45
# Comunicación con los Equipos Móviles                              20
# Se trata de un conflicto familiar                                  6
# Otras                                                              4
#
#                                                     agresor_cantidad  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                   4917
# No se desplazó un Equipo móvil por tratarse de ...               704
# La víctima no aceptó la intervención del Equipo...               195
# No había móviles y/o Equipos para realizar la i...                97
# Está interviniendo o se deriva a otra institución                 74
# Desplazamiento de un Equipo Móvil a donde se en...                53
# Se planificó intervención para otro momento                       45
# Comunicación con los Equipos Móviles                              20
# Se trata de un conflicto familiar                                  6
# Otras                                                              4
#
#                                                     agresor_genero  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                 4070
# No se desplazó un Equipo móvil por tratarse de ...             666
# La víctima no aceptó la intervención del Equipo...             191
# No había móviles y/o Equipos para realizar la i...              94
# Está interviniendo o se deriva a otra institución               67
# Desplazamiento de un Equipo Móvil a donde se en...              51
# Se planificó intervención para otro momento                     42
# Comunicación con los Equipos Móviles                            18
# Se trata de un conflicto familiar                                6
# Otras                                                            4
#
#                                                     agresor_relacion_victima  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                           4066
# No se desplazó un Equipo móvil por tratarse de ...                       679
# La víctima no aceptó la intervención del Equipo...                       193
# No había móviles y/o Equipos para realizar la i...                        94
# Está interviniendo o se deriva a otra institución                         68
# Desplazamiento de un Equipo Móvil a donde se en...                        51
# Se planificó intervención para otro momento                               43
# Comunicación con los Equipos Móviles                                      19
# Se trata de un conflicto familiar                                          6
# Otras                                                                      3
#
#                                                     llamado_fecha  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                4917
# No se desplazó un Equipo móvil por tratarse de ...            704
# La víctima no aceptó la intervención del Equipo...            195
# No había móviles y/o Equipos para realizar la i...             97
# Está interviniendo o se deriva a otra institución              74
# Desplazamiento de un Equipo Móvil a donde se en...             53
# Se planificó intervención para otro momento                    45
# Comunicación con los Equipos Móviles                           20
# Se trata de un conflicto familiar                               6
# Otras                                                           4
#
#                                                     llamado_hora  \
# llamado_derivacion
# Llamante solicitó información y/o orientación               4917
# No se desplazó un Equipo móvil por tratarse de ...           704
# La víctima no aceptó la intervención del Equipo...           195
# No había móviles y/o Equipos para realizar la i...            97
# Está interviniendo o se deriva a otra institución             74
# Desplazamiento de un Equipo Móvil a donde se en...            53
# Se planificó intervención para otro momento                   45
# Comunicación con los Equipos Móviles                          20
# Se trata de un conflicto familiar                              6
# Otras                                                          4
#
#                                                     llamado_provincia  \
# llamado_derivacion
# Llamante solicitó información y/o orientación                    4917
# No se desplazó un Equipo móvil por tratarse de ...                704
# La víctima no aceptó la intervención del Equipo...                195
# No había móviles y/o Equipos para realizar la i...                 97
# Está interviniendo o se deriva a otra institución                  74
# Desplazamiento de un Equipo Móvil a donde se en...                 53
# Se planificó intervención para otro momento                        45
# Comunicación con los Equipos Móviles                               20
# Se trata de un conflicto familiar                                   6
# Otras                                                               4
#
#                                                     llamado_provincia_id
# llamado_derivacion
# Llamante solicitó información y/o orientación                       4917
# No se desplazó un Equipo móvil por tratarse de ...                   704
# La víctima no aceptó la intervención del Equipo...                   195
# No había móviles y/o Equipos para realizar la i...                    97
# Está interviniendo o se deriva a otra institución                     74
# Desplazamiento de un Equipo Móvil a donde se en...                    53
# Se planificó intervención para otro momento                           45
# Comunicación con los Equipos Móviles                                  20
# Se trata de un conflicto familiar                                      6
# Otras                                                                  4

# %%
agresor_victima = df.groupby('agresor_relacion_victima').count()
agresor_victima.sort_values(by='caso_id', ascending=False)
# Out:
#                           caso_id  llamante_descripcion  llamante_genero  \
# agresor_relacion_victima
# Pareja                       1165                  1143             1099
# Ex pareja                    1085                  1077             1057
# Madre                         898                   868              811
# Padre                         706                   692              640
# Hijo/a                        509                   496              479
# Hermano/a                     341                   339              323
# Otro/a no conviviente         201                   199              193
# Otro/a conviviente            154                   148              132
# Padrastro                     120                   117              106
# Abuelo/a                       31                    30               27
# Madrastra                      12                    12               12
#
#                           llamante_vinculo_ninios_presentes  violencia_tipo  \
# agresor_relacion_victima
# Pareja                                                  941            1165
# Ex pareja                                               959            1085
# Madre                                                   754             898
# Padre                                                   560             706
# Hijo/a                                                  426             509
# Hermano/a                                               260             341
# Otro/a no conviviente                                   164             201
# Otro/a conviviente                                      119             154
# Padrastro                                               102             120
# Abuelo/a                                                 27              31
# Madrastra                                                11              12
#
#                           victima_edad  victima_rango_etario  victima_genero  \
# agresor_relacion_victima
# Pareja                             689                   633            1127
# Ex pareja                          621                   578            1056
# Madre                              591                   528             786
# Padre                              506                   460             644
# Hijo/a                             317                   290             494
# Hermano/a                          224                   203             323
# Otro/a no conviviente              129                   119             194
# Otro/a conviviente                  93                    84             135
# Padrastro                           77                    71             108
# Abuelo/a                            23                    21              29
# Madrastra                            7                     7              10
#
#                           victima_cantidad  agresor_cantidad  agresor_genero  \
# agresor_relacion_victima
# Pareja                                1165              1165            1129
# Ex pareja                             1085              1085            1059
# Madre                                  898               898             887
# Padre                                  706               706             696
# Hijo/a                                 509               509             491
# Hermano/a                              341               341             333
# Otro/a no conviviente                  201               201             190
# Otro/a conviviente                     154               154             121
# Padrastro                              120               120             119
# Abuelo/a                                31                31              31
# Madrastra                               12                12              12
#
#                           llamado_derivacion  llamado_fecha  llamado_hora  \
# agresor_relacion_victima
# Pareja                                  1165           1165          1165
# Ex pareja                               1085           1085          1085
# Madre                                    898            898           898
# Padre                                    706            706           706
# Hijo/a                                   509            509           509
# Hermano/a                                341            341           341
# Otro/a no conviviente                    201            201           201
# Otro/a conviviente                       154            154           154
# Padrastro                                120            120           120
# Abuelo/a                                  31             31            31
# Madrastra                                 12             12            12
#
#                           llamado_provincia  llamado_provincia_id
# agresor_relacion_victima
# Pareja                                 1165                  1165
# Ex pareja                              1085                  1085
# Madre                                   898                   898
# Padre                                   706                   706
# Hijo/a                                  509                   509
# Hermano/a                               341                   341
# Otro/a no conviviente                   201                   201
# Otro/a conviviente                      154                   154
# Padrastro                               120                   120
# Abuelo/a                                 31                    31
# Madrastra                                12                    12

# %%
tipo_violencia = df.groupby('violencia_tipo').count()

tipo_violencia.sort_values(by='caso_id', ascending=False)
# Out:
#                                          caso_id  llamante_descripcion  \
# violencia_tipo
# Psicológica                                 3306                  2971
# Física y psicológica                        2514                  2426
# Física, sexual y psicológica                 102                    98
# Económica y psicológica                       84                    82
# Económica, Física y psicológica               78                    76
# Física, psicológica y económica               21                    21
# No aplica                                      7                     4
# Física, sexual, psicológica y económica        3                     2
#
#                                          llamante_genero  \
# violencia_tipo
# Psicológica                                         2690
# Física y psicológica                                2312
# Física, sexual y psicológica                          99
# Económica y psicológica                               82
# Económica, Física y psicológica                       76
# Física, psicológica y económica                       20
# No aplica                                              6
# Física, sexual, psicológica y económica                2
#
#                                          llamante_vinculo_ninios_presentes  \
# violencia_tipo
# Psicológica                                                           2274
# Física y psicológica                                                  2047
# Física, sexual y psicológica                                            87
# Económica y psicológica                                                 71
# Económica, Física y psicológica                                         70
# Física, psicológica y económica                                         19
# No aplica                                                                3
# Física, sexual, psicológica y económica                                  3
#
#                                          victima_edad  victima_rango_etario  \
# violencia_tipo
# Psicológica                                      1577                  1427
# Física y psicológica                             1630                  1505
# Física, sexual y psicológica                       73                    62
# Económica y psicológica                            48                    41
# Económica, Física y psicológica                    50                    47
# Física, psicológica y económica                    14                    14
# No aplica                                           2                     2
# Física, sexual, psicológica y económica             2                     1
#
#                                          victima_genero  victima_cantidad  \
# violencia_tipo
# Psicológica                                        2662              3306
# Física y psicológica                               2326              2514
# Física, sexual y psicológica                         96               102
# Económica y psicológica                              82                84
# Económica, Física y psicológica                      76                78
# Física, psicológica y económica                      20                21
# No aplica                                             4                 7
# Física, sexual, psicológica y económica               2                 3
#
#                                          agresor_cantidad  agresor_genero  \
# violencia_tipo
# Psicológica                                          3306            2561
# Física y psicológica                                 2514            2369
# Física, sexual y psicológica                          102              98
# Económica y psicológica                                84              79
# Económica, Física y psicológica                        78              74
# Física, psicológica y económica                        21              21
# No aplica                                               7               4
# Física, sexual, psicológica y económica                 3               3
#
#                                          agresor_relacion_victima  \
# violencia_tipo
# Psicológica                                                  2579
# Física y psicológica                                         2367
# Física, sexual y psicológica                                   97
# Económica y psicológica                                        79
# Económica, Física y psicológica                                73
# Física, psicológica y económica                                20
# No aplica                                                       4
# Física, sexual, psicológica y económica                         3
#
#                                          llamado_derivacion  llamado_fecha  \
# violencia_tipo
# Psicológica                                            3306           3306
# Física y psicológica                                   2514           2514
# Física, sexual y psicológica                            102            102
# Económica y psicológica                                  84             84
# Económica, Física y psicológica                          78             78
# Física, psicológica y económica                          21             21
# No aplica                                                 7              7
# Física, sexual, psicológica y económica                   3              3
#
#                                          llamado_hora  llamado_provincia  \
# violencia_tipo
# Psicológica                                      3306               3306
# Física y psicológica                             2514               2514
# Física, sexual y psicológica                      102                102
# Económica y psicológica                            84                 84
# Económica, Física y psicológica                    78                 78
# Física, psicológica y económica                    21                 21
# No aplica                                           7                  7
# Física, sexual, psicológica y económica             3                  3
#
#                                          llamado_provincia_id
# violencia_tipo
# Psicológica                                              3306
# Física y psicológica                                     2514
# Física, sexual y psicológica                              102
# Económica y psicológica                                    84
# Económica, Física y psicológica                            78
# Física, psicológica y económica                            21
# No aplica                                                   7
# Física, sexual, psicológica y económica                     3

# %%
quien_llama = df.groupby('llamante_descripcion').count()

quien_llama.sort_values(by='caso_id', ascending=False)
# Out:
#                       caso_id  llamante_genero  \
# llamante_descripcion
# Víctima                  3129             2889
# Familiar                 1383             1263
# Vecina/o                  567              435
# Comisaría                 397              390
# Otra institución          140              135
# Hospital                   37               37
# Agresor/a                  25               25
# Defensoría                  2                2
#
#                       llamante_vinculo_ninios_presentes  violencia_tipo  \
# llamante_descripcion
# Víctima                                            2321            3129
# Familiar                                           1200            1383
# Vecina/o                                            464             567
# Comisaría                                           368             397
# Otra institución                                    107             140
# Hospital                                             32              37
# Agresor/a                                            19              25
# Defensoría                                            2               2
#
#                       victima_edad  victima_rango_etario  victima_genero  \
# llamante_descripcion
# Víctima                       1875                  1714            2862
# Familiar                       809                   721            1273
# Vecina/o                       202                   187             426
# Comisaría                      350                   328             388
# Otra institución                84                    79             135
# Hospital                        29                    27              37
# Agresor/a                       10                    10              23
# Defensoría                       2                     2               2
#
#                       victima_cantidad  agresor_cantidad  agresor_genero  \
# llamante_descripcion
# Víctima                           3129              3129            2819
# Familiar                          1383              1383            1243
# Vecina/o                           567               567             470
# Comisaría                          397               397             384
# Otra institución                   140               140             132
# Hospital                            37                37              36
# Agresor/a                           25                25              24
# Defensoría                           2                 2               2
#
#                       agresor_relacion_victima  llamado_derivacion  \
# llamante_descripcion
# Víctima                                   2827                3129
# Familiar                                  1250                1383
# Vecina/o                                   464                 567
# Comisaría                                  388                 397
# Otra institución                           128                 140
# Hospital                                    37                  37
# Agresor/a                                   25                  25
# Defensoría                                   2                   2
#
#                       llamado_fecha  llamado_hora  llamado_provincia  \
# llamante_descripcion
# Víctima                        3129          3129               3129
# Familiar                       1383          1383               1383
# Vecina/o                        567           567                567
# Comisaría                       397           397                397
# Otra institución                140           140                140
# Hospital                         37            37                 37
# Agresor/a                        25            25                 25
# Defensoría                        2             2                  2
#
#                       llamado_provincia_id
# llamante_descripcion
# Víctima                               3129
# Familiar                              1383
# Vecina/o                               567
# Comisaría                              397
# Otra institución                       140
# Hospital                                37
# Agresor/a                               25
# Defensoría                               2

# %% [markdown]
# # What is the relationship between gender and agression?

# %%
sns.countplot( x = 'victima_genero', hue = 'agresor_genero', palette = "coolwarm", data = df)
plt.title('Género de la víctima vs género del agresor')
plt.xlabel("Género de la víctima")
plt.ylabel("Cantidad de casos")

plt.legend(fontsize = 12, \
               bbox_to_anchor= (1.01, 1), \
               title="Género del agresor", \
               title_fontsize = 10)

# %%
sns.barplot(x = 'victima_edad', data = df)
# Out:
# <AxesSubplot:xlabel='victima_edad'>

# %%
sns.relplo(kind='pie', x='llamado_derivacion', y='violencia_tipo', title = 'Sales by Zone', 
cmap='Dark2', autopct="%.1f%%", figsize = (10,6), legend=False);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16064/3480362221.py in <module>
# ----> 1 sns.relplo(kind='pie', x='llamado_derivacion', y='violencia_tipo', title = 'Sales by Zone',
#       2 cmap='Dark2', autopct="%.1f%%", figsize = (10,6), legend=False);
#
# AttributeError: module 'seaborn' has no attribute 'relplo'
